# %% [markdown]
# <a href="https://colab.research.google.com/github/MUSSAFARA-RIAZ/Numpy-Learning/blob/main/Pandas_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas Library
# Useful for data processing and analysis
# Pandas Data frame
# 2 dimensional tabular structure with labeled axes(rows and columns)

# %%
import pandas as pd
import numpy as np
# importing the boston house price data
df=pd.read_csv('/content/HousingData.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222     18.7  396.90    NaN  36.2
#
# [5 rows x 14 columns]

# %%
df_features=df.drop(columns=['MEDV'])
df_features
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD  TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...    1  296     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...    2  242     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...    2  242     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...    3  222     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...    3  222     18.7  396.90    NaN
# ..       ...   ...    ...   ...    ...  ...  ...  ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...    1  273     21.0  391.99    NaN
# 502  0.04527   0.0  11.93   0.0  0.573  ...    1  273     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...    1  273     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...    1  273     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...    1  273     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
df_features.shape
# Out:
# (506, 13)

# %%
#Exporting a dataframe tp csv
df.to_csv('boston.csv')

# %%
# Creating a dataframe with random values
random_df=pd.DataFrame(np.random.rand(100,10))
random_df.head()
# Out:
#           0         1         2  ...         7         8         9
# 0  0.509513  0.862915  0.284914  ...  0.014737  0.751541  0.330079
# 1  0.401019  0.415820  0.410857  ...  0.323101  0.930468  0.262708
# 2  0.311245  0.616278  0.403964  ...  0.625065  0.505867  0.914773
# 3  0.829726  0.403890  0.185683  ...  0.143255  0.553084  0.037131
# 4  0.927635  0.674872  0.485646  ...  0.428010  0.087509  0.043280
#
# [5 rows x 10 columns]

# %%
random_df.shape
# Out:
# (100, 10)

# %%
#Inspecting a Data Frame
# finding no of rows and column
# shape method
random_df.tail()
# Out:
#            0         1         2  ...         7         8         9
# 95  0.678678  0.777229  0.123459  ...  0.212899  0.648509  0.408098
# 96  0.772376  0.734938  0.132857  ...  0.469410  0.681662  0.491281
# 97  0.030139  0.134519  0.426769  ...  0.033441  0.868211  0.322128
# 98  0.634742  0.288391  0.642516  ...  0.743146  0.078863  0.304833
# 99  0.367862  0.725048  0.001171  ...  0.654880  0.096355  0.734446
#
# [5 rows x 10 columns]

# %%
# Information about dataset
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
# dtypes: float64(11), int64(2)
# memory usage: 51.5 KB

# %%
# describing dataset
df_features.describe()
# Out:
#              CRIM          ZN       INDUS  ...     PTRATIO           B       LSTAT
# count  486.000000  486.000000  486.000000  ...  506.000000  506.000000  486.000000
# mean     3.611874   11.211934   11.083992  ...   18.455534  356.674032   12.715432
# std      8.720192   23.388876    6.835896  ...    2.164946   91.294864    7.155871
# min      0.006320    0.000000    0.460000  ...   12.600000    0.320000    1.730000
# 25%      0.081900    0.000000    5.190000  ...   17.400000  375.377500    7.125000
# 50%      0.253715    0.000000    9.690000  ...   19.050000  391.440000   11.430000
# 75%      3.560263   12.500000   18.100000  ...   20.200000  396.225000   16.955000
# max     88.976200  100.000000   27.740000  ...   22.000000  396.900000   37.970000
#
# [8 rows x 13 columns]

# %%
# finding the number of missing values in each columns
df_features.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# dtype: int64

# %%
# from sklearn.datasets import load_diabetes
# diabetes_dataset=load_diabetes()
# diabetes_dataset
# diabetes_df=pd.DataFrame(diabetes_dataset.data, columns=diabetes_dataset.feature_names)
# diabetes_df.head()

# %%
diabetes_df=pd.read_csv('/content/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
# Counting the values based on the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# Group the values based on the mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  ...  DiabetesPedigreeFunction        Age
# Outcome                           ...
# 0           3.298000  109.980000  ...                  0.429734  31.190000
# 1           4.865672  141.257463  ...                  0.550500  37.067164
#
# [2 rows x 8 columns]

# %%
# Statistical Measures
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#mean value column wise
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
# standard deviation- column wise
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
# Minimum Value
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
# max value
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# All the statistical measure about df
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  ...         Age     Outcome
# count   768.000000  768.000000  ...  768.000000  768.000000
# mean      3.845052  120.894531  ...   33.240885    0.348958
# std       3.369578   31.972618  ...   11.760232    0.476951
# min       0.000000    0.000000  ...   21.000000    0.000000
# 25%       1.000000   99.000000  ...   24.000000    0.000000
# 50%       3.000000  117.000000  ...   29.000000    0.000000
# 75%       6.000000  140.250000  ...   41.000000    1.000000
# max      17.000000  199.000000  ...   81.000000    1.000000
#
# [8 rows x 9 columns]

# %%
# Manipulating a dataframe
# Adding a column in a dataframe
diabetes_df['BloodPressurenew'] = np.random.rand(768)

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  ...  Age  Outcome  BloodPressurenew
# 0              6      148             72  ...   50        1          0.848473
# 1              1       85             66  ...   31        0          0.780437
# 2              8      183             64  ...   32        1          0.313624
# 3              1       89             66  ...   21        0          0.836500
# 4              0      137             40  ...   33        1          0.499782
# ..           ...      ...            ...  ...  ...      ...               ...
# 763           10      101             76  ...   63        0          0.311924
# 764            2      122             70  ...   27        0          0.453889
# 765            5      121             72  ...   30        0          0.168707
# 766            1      126             60  ...   47        1          0.543192
# 767            1       93             70  ...   23        0          0.456838
#
# [768 rows x 10 columns]

# %%
#Removing a row
diabetes_df.drop(index=0, axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...  Age  Outcome  BloodPressurenew
# 1              1       85             66  ...   31        0          0.780437
# 2              8      183             64  ...   32        1          0.313624
# 3              1       89             66  ...   21        0          0.836500
# 4              0      137             40  ...   33        1          0.499782
# 5              5      116             74  ...   30        0          0.366360
# ..           ...      ...            ...  ...  ...      ...               ...
# 763           10      101             76  ...   63        0          0.311924
# 764            2      122             70  ...   27        0          0.453889
# 765            5      121             72  ...   30        0          0.168707
# 766            1      126             60  ...   47        1          0.543192
# 767            1       93             70  ...   23        0          0.456838
#
# [767 rows x 10 columns]

# %%
#drop a column
diabetes_df.drop(columns='SkinThickness',axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  ...  Age  Outcome  BloodPressurenew
# 0              6      148             72  ...   50        1          0.848473
# 1              1       85             66  ...   31        0          0.780437
# 2              8      183             64  ...   32        1          0.313624
# 3              1       89             66  ...   21        0          0.836500
# 4              0      137             40  ...   33        1          0.499782
# ..           ...      ...            ...  ...  ...      ...               ...
# 763           10      101             76  ...   63        0          0.311924
# 764            2      122             70  ...   27        0          0.453889
# 765            5      121             72  ...   30        0          0.168707
# 766            1      126             60  ...   47        1          0.543192
# 767            1       93             70  ...   23        0          0.456838
#
# [768 rows x 9 columns]

# %%
#Locating a row using the index column
diabetes_df.iloc[2]
# Out:
# Pregnancies                   8.000000
# Glucose                     183.000000
# BloodPressure                64.000000
# SkinThickness                 0.000000
# Insulin                       0.000000
# BMI                          23.300000
# DiabetesPedigreeFunction      0.672000
# Age                          32.000000
# Outcome                       1.000000
# BloodPressurenew              0.313624
# Name: 2, dtype: float64

# %%
# Locating a particular column
diabetes_df.iloc[:,3]
diabetes_df_final=diabetes_df.drop(columns='BloodPressurenew')
diabetes_df_final
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
# Correlation
# 1. Positive Correlation
# 2. Negatice correlation
diabetes_df_final.corr()
# Out:
#                           Pregnancies   Glucose  ...       Age   Outcome
# Pregnancies                  1.000000  0.129459  ...  0.544341  0.221898
# Glucose                      0.129459  1.000000  ...  0.263514  0.466581
# BloodPressure                0.141282  0.152590  ...  0.239528  0.065068
# SkinThickness               -0.081672  0.057328  ... -0.113970  0.074752
# Insulin                     -0.073535  0.331357  ... -0.042163  0.130548
# BMI                          0.017683  0.221071  ...  0.036242  0.292695
# DiabetesPedigreeFunction    -0.033523  0.137337  ...  0.033561  0.173844
# Age                          0.544341  0.263514  ...  1.000000  0.238356
# Outcome                      0.221898  0.466581  ...  0.238356  1.000000
#
# [9 rows x 9 columns]
